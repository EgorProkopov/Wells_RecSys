# %%
import sys
import os
sys.path.append(os.getcwd() + "/../")

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd

# %%
class WellSimMetric:
    """
    Рассчитывает похожесть двух скважин.

    Мы называем скважины похожими, если при построении линейных регрессий 
    они ведут себя на интервалах одинаково. Под "одинаково" я имею в виду, 
    что забойное давление при одиныковых условиях у них не отличается более,
    чем на 10%.
    """

    def __init__(self, 
                 X1_train: np.ndarray, 
                 X2_train: np.ndarray, 
                 y1_train: np.ndarray, 
                 y2_train: np.ndarray):
        """Initialization and train linear regression.

        Args:
            X1_train (np.ndarray): фичи для скважины 1
            X2_train (np.ndarray): для 2
            y1_train (np.ndarray): давление на забое для скважины 1
            y2_train (np.ndarray): для 2
        """
        self.X1_train = X1_train
        self.X2_train = X2_train
        self.y1_train = y1_train
        self.y2_train = y2_train

        # Fit linear regression models
        self.model1 = LinearRegression().fit(X1_train, y1_train)
        self.model2 = LinearRegression().fit(X2_train, y2_train)
    
    def get_error(self, y1_pred: np.ndarray, y2_pred: np.ndarray) -> np.ndarray:
        """Подсчитывает ошибку между двумя предсказаниями

        Args:
            y1_pred (np.ndarray): предсказанное давление на забое для скважины 1
            y2_pred (np.ndarray): для 2
        """
        return np.abs(y1_pred - y2_pred) / ((y1_pred + y2_pred) / 2)

    def get_sim(self):
        X = np.concatenate([self.X1_train, self.X2_train])

        # Predict target variable for both wells
        y1_pred = self.model1.predict(X)
        y2_pred = self.model2.predict(X)

        # Calculate similarity
        similarity = (self.get_error(y1_pred, y2_pred) <= 0.1).astype(int)

        return similarity

# %%
df = pd.read_csv("../data/cleaned/data.csv", index_col=0)
df
# Out:
#      Обводненность_для_расчета_PVT_параметров  Глубина_по_стволу_cs  \
# 0                                    1.200000                3026.0
# 1                                   89.000000                3160.0
# 2                                   61.099998                3160.0
# 3                                   94.150002                3491.9
# 4                                   82.199997                3490.6
# ..                                        ...                   ...
# 175                                 84.300003                3656.0
# 176                                 91.800003                3426.0
# 177                                 89.650002                3453.0
# 178                                 80.699997                3160.0
# 179                                 70.000000                3054.0
#
#      Внутренний_диаметр_эксплуатационной_колонны_cs  \
# 0                                            0.1130
# 1                                            0.1596
# 2                                            0.1596
# 3                                            0.1596
# 4                                            0.1596
# ..                                              ...
# 175                                          0.1596
# 176                                          0.1596
# 177                                          0.1596
# 178                                          0.1596
# 179                                          0.1596
#
#      Внутренняя_шероховатость_эксплуатационной_колонны_cs  Глубина_по_стволу  \
# 0                                             0.000152               2851.75
# 1                                             0.000015               3145.00
# 2                                             0.000015               3145.00
# 3                                             0.000152               3135.00
# 4                                             0.000152               3149.00
# ..                                                 ...                   ...
# 175                                           0.000152               3314.37
# 176                                           0.000152               3157.89
# 177                                           0.000015               3057.00
# 178                                           0.000015               3058.50
# 179                                           0.000152               2838.75
#
#      Внутренний_диаметр_НКТ  Внутренняя_шероховатость_НКТ  \
# 0                     0.062                      0.000152
# 1                     0.062                      0.000015
# 2                     0.062                      0.000015
# 3                     0.062                      0.000152
# 4                     0.062                      0.000152
# ..                      ...                           ...
# 175                   0.062                      0.000015
# 176                   0.062                      0.000152
# 177                   0.062                      0.000015
# 178                   0.062                      0.000015
# 179                   0.062                      0.000152
#
#      Внешний_диаметр_НКТ  Внутренний_диаметр_эксплуатационной_колонны  \
# 0                  0.073                                       0.1598
# 1                  0.073                                       0.1596
# 2                  0.073                                       0.1596
# 3                  0.073                                       0.1596
# 4                  0.073                                       0.1596
# ..                   ...                                          ...
# 175                0.073                                       0.1596
# 176                0.073                                       0.1596
# 177                0.073                                       0.1596
# 178                0.073                                       0.1596
# 179                0.073                                       0.1596
#
#      FILTERED_MD_LAST_VALUE  ...  Коэффициент_продуктиности  \
# 0                   3026.00  ...                   5.967998
# 1                   3960.00  ...                   5.503470
# 2                   3960.00  ...                   6.423728
# 3                   3491.90  ...                   0.574879
# 4                   3625.24  ...                   4.112801
# ..                      ...  ...                        ...
# 175                 4014.00  ...                   2.555688
# 176                 3450.00  ...                   2.136903
# 177                 3590.00  ...                  13.460412
# 178                 3960.00  ...                   2.431851
# 179                 3054.00  ...                   1.405998
#
#      Глубина_спуска_ЭЦН_по_стволу_MD  Частота_ЭЦН  Количество_ступеней  \
# 0                        2851.749877    60.000000                  354
# 1                        3144.999921    46.000000                  401
# 2                        3144.999921    57.000000                  375
# 3                        3134.999862    47.000000                  418
# 4                        3149.000123    51.200001                  404
# ..                               ...          ...                  ...
# 175                      3316.769902    52.500000                  318
# 176                      3157.889925    53.000000                  342
# 177                      3056.999934    47.900002                  318
# 178                      3058.500122    47.500000                  401
# 179                      2838.750037    57.900002                  400
#
#      Коэффициент_износа  Содержание_растворенного_газа  Плотность_нефти  \
# 0                  0.90                     143.899995       867.399978
# 1                  0.00                     255.133001       858.935001
# 2                  0.50                     255.133001       858.935001
# 3                 -0.05                     255.132006       858.935001
# 4                  0.20                     255.132006       858.935001
# ..                  ...                            ...              ...
# 175                0.25                     255.132006       858.935001
# 176                0.00                     130.000005       869.000005
# 177                0.02                     130.000005       869.000005
# 178               -0.25                     255.133001       858.935001
# 179                0.32                     255.132006       858.935001
#
#      Удельный_вес_газа  Корреляция_вязкости_нефти  Пластовое_давление
# 0              0.87940                          1          300.103133
# 1              0.66160                          1          218.711452
# 2              0.66160                          1          160.364419
# 3              0.66160                          2          187.037349
# 4              0.66160                          2          186.350903
# ..                 ...                        ...                 ...
# 175            0.66160                          2          148.400821
# 176            0.79833                          1          205.963356
# 177            0.79833                          1          124.571692
# 178            0.66160                          1          161.737294
# 179            0.66160                          2          125.552318
#
# [180 rows x 22 columns]

# %%
df.corr().abs().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f3c87_row0_col0, #T_f3c87_row1_col1, #T_f3c87_row2_col2, #T_f3c87_row3_col3, #T_f3c87_row4_col4, #T_f3c87_row5_col5, #T_f3c87_row6_col6, #T_f3c87_row7_col7, #T_f3c87_row8_col8, #T_f3c87_row9_col9, #T_f3c87_row10_col10, #T_f3c87_row11_col11, #T_f3c87_row12_col12, #T_f3c87_row13_col13, #T_f3c87_row14_col14, #T_f3c87_row15_col15, #T_f3c87_row16_col16, #T_f3c87_row17_col17, #T_f3c87_row18_col18, #T_f3c87_row19_col19, #T_f3c87_row20_col20, #T_f3c87_row21_col21 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f3c87_row0_col1, #T_f3c87_row0_col17, #T_f3c87_row3_col12, #T_f3c87_row9_col15, #T_f3c87_row11_col12, #T_f3c87_row12_col20, #T_f3c87_row14_col10 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_f3c87_row0_col2, #T_f3c87_row0_col7 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_f3c87_row0_col3, #T_f3c87_row20_col13 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_f3c87_row0_