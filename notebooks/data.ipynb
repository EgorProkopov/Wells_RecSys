# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data process

# %%
data_paths = {
    'emulsion': '..\data\cleaned\data_emulsion.csv',
    # 'equipments': '..\data\cleaned\data_emulsion.csv',  # pass
    'incline': '..\data\cleaned\data_incline.csv',  # done
    'ipr': '..\data\cleaned\data_ipr.csv',
    'lift': '..\data\cleaned\data_lift.csv',
    'pvt': '..\data\cleaned\data_pvt.csv',
    "pvt_matching": '..\data\cleaned\data_pvt_matching.csv',
    'vip_ipr': '..\data\cleaned\data_vlp_ipr.csv'
}

# %%
dfs = {data_name: pd.read_csv(data_path) for data_name, data_path in data_paths.items()}
# Out:
# {'emulsion':         Unnamed: 0      WELLNAME   EMULSION_MODEL  \
# 0    COLUMN_LABELS  Имя_скважины  Модель_эмульсии
# 1           1-Tunj        1-Tunj               No
# 2          1001_AR       1001_AR               No
# 3          1003_AR       1003_AR               No
# 4          1004_AR       1004_AR               No
# ..             ...           ...              ...
# 176     SB_1225_AR    SB_1225_AR               No
# 177    SB_201_UTBG   SB_201_UTBG               No
# 178    SB_208_UTBG   SB_208_UTBG               No
# 179    SB_216_UTBG   SB_216_UTBG               No
# 180       SB_47_AR      SB_47_AR               No
#
#                                  EMULSION_WCT          EMULSION_OCCURENCE  \
# 0    Обводненность_для_расчета_PVT_параметров  Место_образования_эмульсии
# 1                                 1.200000048     No_Emulsion_Corrections
# 2                                          89     No_Emulsion_Corrections
# ...

# %%
for df_name, df in dfs.items():
    print(df_name, '\n')
    print(df)
    print('\n')
# Out:
# emulsion
#
#         Unnamed: 0      WELLNAME   EMULSION_MODEL  \
# 0    COLUMN_LABELS  Имя_скважины  Модель_эмульсии
# 1           1-Tunj        1-Tunj               No
# 2          1001_AR       1001_AR               No
# 3          1003_AR       1003_AR               No
# 4          1004_AR       1004_AR               No
# ..             ...           ...              ...
# 176     SB_1225_AR    SB_1225_AR               No
# 177    SB_201_UTBG   SB_201_UTBG               No
# 178    SB_208_UTBG   SB_208_UTBG               No
# 179    SB_216_UTBG   SB_216_UTBG               No
# 180       SB_47_AR      SB_47_AR               No
#
#                                  EMULSION_WCT          EMULSION_OCCURENCE  \
# 0    Обводненность_для_расчета_PVT_параметров  Место_образования_эмульсии
# 1                                 1.200000048     No_Emulsion_Corrections
# 2                                          89     No_Emulsion_Corrections
# ...
